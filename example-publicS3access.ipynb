# %%
import s3fs

# %%
bucket = "68e13833a1624f43ba2cac01376a18af:destine-climate-dt"
prefix = ""
s3_endpoint = "https://objects.eodc.eu"

# Create the S3FileSystem with a custom endpoint
fs = s3fs.S3FileSystem(
    anon=True,
    client_kwargs={
        "endpoint_url": s3_endpoint
    }
)

# unregister handler to make boto3 work with CEPH
handlers = fs.s3.meta.events._emitter._handlers
handlers_to_unregister = handlers.prefix_search("before-parameter-build.s3")
handler_to_unregister = handlers_to_unregister[0]
fs._s3.meta.events._emitter.unregister(
    "before-parameter-build.s3", handler_to_unregister
)

# List all objects in the bucket
files = fs.ls(f"{bucket}", detail=True)  # Set detail=True to get metadata

# Print file names and metadata
for file in files:
    print(file["Key"])
# Out:
# 68e13833a1624f43ba2cac01376a18af:destine-climate-dt/ICON_sfc_CMIP6.zarr
# 68e13833a1624f43ba2cac01376a18af:destine-climate-dt/ICON_sfc_ScenarioMIP.zarr
# 68e13833a1624f43ba2cac01376a18af:destine-climate-dt/IFS-FESMO-cont-rechunked.zarr
# 68e13833a1624f43ba2cac01376a18af:destine-climate-dt/IFS-NEMO-CMIP6-rechunked.zarr
# 68e13833a1624f43ba2cac01376a18af:destine-climate-dt/IFS-NEMO-CMIP6-rechunkedTS.zarr
# 68e13833a1624f43ba2cac01376a18af:destine-climate-dt/IFS-NEMO-down
# 68e13833a1624f43ba2cac01376a18af:destine-climate-dt/IFS-NEMO-sfc-CMIP6-consolidated_rechunked.zarr
# 68e13833a1624f43ba2cac01376a18af:destine-climate-dt/IFS-NEMO-sfc-CMIP6-consolidated_rechunked.zarr_tmp
# 68e13833a1624f43ba2cac01376a18af:destine-climate-dt/IFS-NEMO_sfc_CMIP6.zarr
# 68e13833a1624f43ba2cac01376a18af:destine-climate-dt/IFS-NEMO_sfc_ScenarioMIP.zarr

# %%
import xarray as xr
xr.__version__
# Out:
# '2025.12.0'

# %% [markdown]
# # Read IFS-NEMO-CMIP6-rechunkedTS.zarr
#
# Variables 2t and tp

# %%
zarr_store = "IFS-NEMO-CMIP6-rechunkedTS.zarr"
climate_dt = xr.open_zarr(f"{s3_endpoint}/{bucket}/{zarr_store}")

# %%
climate_dt
# Out:
# <xarray.Dataset> Size: 7GB
# Dimensions:    (datetimes: 215256, points: 2067)
# Coordinates:
#   * datetimes  (datetimes) <U20 17MB '1990-01-01 00:00:00Z' ... '2002-02-28 2...
#   * points     (points) int64 17kB 0 1 2 3 4 5 ... 2061 2062 2063 2064 2065 2066
#     latitude   (points) float64 17kB dask.array<chunksize=(2067,), meta=np.ndarray>
#     longitude  (points) float64 17kB dask.array<chunksize=(2067,), meta=np.ndarray>
# Data variables:
#     2t         (datetimes, points) float64 4GB dask.array<chunksize=(215256, 100), meta=np.ndarray>
#     tp         (datetimes, points) float64 4GB dask.array<chunksize=(215256, 100), meta=np.ndarray>
# Attributes: (12/15)
#     activity:     cmip6
#     class:        d1
#     dataset:      climate-dt
#     date:         1990-01-01 00:00:00Z
#     experiment:   hist
#     expver:       0001
#     ...           ...
#     number:       0
#     realization:  1
#     resolution:   high
#     step:         0
#     stream:       clte
# ...

# %% [markdown]
# # Read IFS-FESMO-cont-rechunked.zarr
#
# Variable sd

# %%
zarr_store = "IFS-FESMO-cont-rechunked.zarr"
snow = xr.open_zarr(f"{s3_endpoint}/{bucket}/{zarr_store}")
snow
# Out:
# <xarray.Dataset> Size: 107MB
# Dimensions:    (datetimes: 2556, points: 5203)
# Coordinates:
#   * datetimes  (datetimes) <U20 204kB '2017-01-01T10:00:00Z' ... '2023-12-31T...
#   * points     (points) int64 42kB 0 1 2 3 4 5 ... 5197 5198 5199 5200 5201 5202
#     latitude   (points) float64 42kB dask.array<chunksize=(5203,), meta=np.ndarray>
#     levelist   (points) float64 42kB dask.array<chunksize=(5203,), meta=np.ndarray>
#     longitude  (points) float64 42kB dask.array<chunksize=(5203,), meta=np.ndarray>
# Data variables:
#     sd         (datetimes, points) float64 106MB dask.array<chunksize=(2556, 1000), meta=np.ndarray>
# Attributes: (12/16)
#     activity:       story-nudging
#     class:          d1
#     dataset:        climate-dt
#     Forecast date:  2017-01-01T10:00:00Z
#     experiment:     cont
#     expver:         0001
#     ...             ...
#     resolution:     high
#     stream:         clte
#     type:           fc
#     number:         0
# ...
