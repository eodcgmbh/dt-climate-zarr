# %%
import pystac
from datetime import datetime
import zarr

# %%
s3_endpoint = "https://objects.eodc.eu"
bucket = "68e13833a1624f43ba2cac01376a18af:destine-climate-dt/vsw"

# %%
link = f"{s3_endpoint}/{bucket}"
link
# Out:
# 'https://objects.eodc.eu/68e13833a1624f43ba2cac01376a18af:destine-climate-dt/vsw'

# %%
user = "" #prod
key = "" #prod

# user = "" #dev
# key = "" #dev

# %%
extent = pystac.Extent(
    spatial=pystac.SpatialExtent([[9.47,46.34,17.22,49.04]]),
    temporal=pystac.TemporalExtent([[datetime(1990, 1, 1), datetime(2049, 12, 31)]])
)

collection = pystac.Collection(
    id="climatedt-vsw",
    title="DestinE Climate Change Adaptation Digital Twin Volumetric Soil moisture",
    description="The Destination Earth Climate Change Adaptation Digital Twin (Climate DT) is an operational modeling system that delivers globally consistent, high-resolution climate and climate-impact data at spatial resolutions fine enough to capture many climate change effects and extreme weather events. The system supports two main use cases: projecting how the climate system may evolve over multi-decadal periods, and evaluating what-if scenarios, both of which help inform climate adaptation planning throughout Europe. This collection draws on Generation 2 data and covers the volumetric soil moisture (vsw). More information here: https://platform.destine.eu/services/documents-and-api/doc/?service_name=climate-dt-user-guide",
    extent=extent)

collection.stac_extensions = [
    "https://stac-extensions.github.io/zarr/v1.1.0/schema.json",
]

collection.license = "CC-BY-4.0"


# collection.links = [l for l in collection.links if l.rel != "item"]

# %%
thumbnail = pystac.Asset(
    href=f"{link}/thumbnail.png",
    media_type="image/png",
    roles=["thumbnail"],
    title="ClimateDT vsw thumbnail",
    # description="Link to thumbnail: https://destine.ecmwf.int/harnessing-the-climate-change-adaptation-digital-twin-for-wind-energy/"
)

collection.add_asset("thumbnail", thumbnail)

# %%
bbox = [9.47,46.34,17.22,49.04]
geometry = {
    "type": "Polygon",
    "coordinates": [[
        [bbox[0], bbox[1]],
        [bbox[2], bbox[1]],
        [bbox[2], bbox[3]],
        [bbox[0], bbox[3]],
        [bbox[0], bbox[1]],
    ]]
}

# %%
item_fesom = pystac.Item(
    id="IFS-FESOM",
    geometry=geometry,
    bbox=bbox,
    datetime=None,  # because it's a time range
    properties={
        "title": "Volumetric soil moisture IFS-FESOM",
        "description": "IFS-FESOM couples ECMWF's IFS atmosphere model with AWI's FESOM2 ocean and sea-ice model in a sequential, single-executable framework, exchanging fluxes and surface fields hourly via Gaussian distance-weighted remapping. It also includes indirect wave coupling through ecWAM and direct runoff coupling from IFS to FESOM, and has been used both for the core Climate DT simulations and for high-resolution (10km) storyline experiments.",
        "start_datetime": datetime(1990, 1, 1).isoformat() + "Z",
        "end_datetime": datetime(2049, 12, 31).isoformat() + "Z",
    },
)

# item_nemo_ScenarioMIP.links = [link for link in item_nemo_ScenarioMIP.links if link.href is not None]

# %%
asset_fesom_hist_1 = pystac.Asset(
    href=f"{link}/zarr/IFS-FESOM.zarr/hist/1",
    media_type="application/vnd.zarr; version=3",
    roles=["data"],
    title="VSM IFS-FESOM historical simulation Level 1",
    description="Model: IFS-FESOM \nLevel: 1 \nExperiment: hist \n Resolution: high \n Time: 1990-2014",
)
asset_fesom_hist_1.extra_fields.update({
    "xarray:open_zarr_kwargs": {"zarr_format": 3, "consolidated": True},
})
item_fesom.add_asset("hist-1", asset_fesom_hist_1)


asset_fesom_hist_2 = pystac.Asset(
    href=f"{link}/zarr/IFS-FESOM.zarr/hist/2",
    media_type="application/vnd.zarr; version=3",
    roles=["data"],
    title="VSM IFS-FESOM historical simulation Level 2",
    description="Model: IFS-FESOM \nLevel: 2 \nExperiment: hist \n Resolution: high \n Time: 1990-2014",
)
asset_fesom_hist_2.extra_fields.update({
    "xarray:open_zarr_kwargs": {"zarr_format": 3, "consolidated": True},
})
item_fesom.add_asset("hist-2", asset_fesom_hist_2)


asset_fesom_hist_3 = pystac.Asset(
    href=f"{link}/zarr/IFS-FESOM.zarr/hist/3",
    media_type="application/vnd.zarr; version=3",
    roles=["data"],
    title="VSM IFS-FESOM historical simulation Level 3",
    description="Model: IFS-FESOM \nLevel: 3 \nExperiment: hist \n Resolution: high \n Time: 1990-2014",
)
asset_fesom_hist_3.extra_fields.update({
    "xarray:open_zarr_kwargs": {"zarr_format": 3, "consolidated": True},
})
item_fesom.add_asset("hist-3", asset_fesom_hist_3)

# %%
asset_fesom_ssp3_1 = pystac.Asset(
    href=f"{link}/zarr/IFS-FESOM.zarr/SSP3-7.0/1",
    media_type="application/vnd.zarr; version=3",
    roles=["data"],
    title="VSM IFS-FESOM projection Level 1",
    description="Model: IFS-FESOM \nLevel: 1 \nExperiment: SSP3-7.0 \n Resolution: high \n Time: 2015-2049",
)
asset_fesom_ssp3_1.extra_fields.update({
    "xarray:open_zarr_kwargs": {"zarr_format": 3, "consolidated": True},
})
item_fesom.add_asset("ssp3-1", asset_fesom_ssp3_1)


asset_fesom_ssp3_2 = pystac.Asset(
    href=f"{link}/zarr/IFS-FESOM.zarr/SSP3-7.0/2",
    media_type="application/vnd.zarr; version=3",
    roles=["data"],
    title="VSM IFS-FESOM projection Level 2",
    description="Model: IFS-FESOM \nLevel: 2 \nExperiment: SSP3-7.0 \n Resolution: high \n Time: 2015-2049",
)
asset_fesom_ssp3_2.extra_fields.update({
    "xarray:open_zarr_kwargs": {"zarr_format": 3, "consolidated": True},
})
item_fesom.add_asset("ssp3-2", asset_fesom_ssp3_2)


asset_fesom_ssp3_3 = pystac.Asset(
    href=f"{link}/zarr/IFS-FESOM.zarr/SSP3-7.0/3",
    media_type="application/vnd.zarr; version=3",
    roles=["data"],
    title="VSM IFS-FESOM projection Level 3",
    description="Model: IFS-FESOM \nLevel: 3 \nExperiment: SSP3-7.0 \n Resolution: high \n Time: 2015-2049",
)
asset_fesom_ssp3_3.extra_fields.update({
    "xarray:open_zarr_kwargs": {"zarr_format": 3, "consolidated": True},
})
item_fesom.add_asset("ssp3-3", asset_fesom_ssp3_3)

# %%
item_icon = pystac.Item(
    id="ICON",
    geometry=geometry,
    bbox=bbox,
    datetime=None,  # because it's a time range
    properties={
        "title": "Volumetric soil moisture ICON",
        "description": "ICON (ICOsahedral Nonhydrostatic) is the global storm-resolving Earth system model developed by DWD, MPI-M and DKRZ, run as one of the baseline coupled configurations for Destination Earth's Climate DT. This dataset combines a historical simulation (1990-2014) with its projection continuation under SSP3-7.0 (2015-2049).",
        "start_datetime": datetime(1990, 1, 1).isoformat() + "Z",
        "end_datetime": datetime(2049, 12, 31).isoformat() + "Z",
    },
)

asset_icon_hist_1 = pystac.Asset(
    href=f"{link}/zarr/ICON2.zarr/hist/1",
    media_type="application/vnd.zarr; version=3",
    roles=["data"],
    title="VSM ICON historical simulation Level 1",
    description="Model: ICON \nLevel: 1 \nExperiment: hist \n Resolution: high \n Time: 1990-2014",
)
asset_icon_hist_1.extra_fields.update({
    "xarray:open_zarr_kwargs": {"zarr_format": 3, "consolidated": True},
})
item_icon.add_asset("hist-1", asset_icon_hist_1)


asset_icon_hist_2 = pystac.Asset(
    href=f"{link}/zarr/ICON2.zarr/hist/2",
    media_type="application/vnd.zarr; version=3",
    roles=["data"],
    title="VSM ICON historical simulation Level 2",
    description="Model: ICON \nLevel: 2 \nExperiment: hist \n Resolution: high \n Time: 1990-2014",
)
asset_icon_hist_2.extra_fields.update({
    "xarray:open_zarr_kwargs": {"zarr_format": 3, "consolidated": True},
})
item_icon.add_asset("hist-2", asset_icon_hist_2)


asset_icon_hist_3 = pystac.Asset(
    href=f"{link}/zarr/ICON2.zarr/hist/3",
    media_type="application/vnd.zarr; version=3",
    roles=["data"],
    title="VSM ICON historical simulation Level 3",
    description="Model: ICON \nLevel: 3 \nExperiment: hist \n Resolution: high \n Time: 1990-2014",
)
asset_icon_hist_3.extra_fields.update({
    "xarray:open_zarr_kwargs": {"zarr_format": 3, "consolidated": True},
})
item_icon.add_asset("hist-3", asset_icon_hist_3)


asset_icon_ssp3_1 = pystac.Asset(
    href=f"{link}/zarr/ICON2.zarr/SSP3-7.0/1",
    media_type="application/vnd.zarr; version=3",
    roles=["data"],
    title="VSM ICON projection Level 1",
    description="Model: ICON \nLevel: 1 \nExperiment: SSP3-7.0 \n Resolution: high \n Time: 2015-2049",
)
asset_icon_ssp3_1.extra_fields.update({
    "xarray:open_zarr_kwargs": {"zarr_format": 3, "consolidated": True},
})
item_icon.add_asset("ssp3-1", asset_icon_ssp3_1)


asset_icon_ssp3_2 = pystac.Asset(
    href=f"{link}/zarr/ICON2.zarr/SSP3-7.0/2",
    media_type="application/vnd.zarr; version=3",
    roles=["data"],
    title="VSM ICON projection Level 2",
    description="Model: ICON \nLevel: 2 \nExperiment: SSP3-7.0 \n Resolution: high \n Time: 2015-2049",
)
asset_icon_ssp3_2.extra_fields.update({
    "xarray:open_zarr_kwargs": {"zarr_format": 3, "consolidated": True},
})
item_icon.add_asset("ssp3-2", asset_icon_ssp3_2)


asset_icon_ssp3_3 = pystac.Asset(
    href=f"{link}/zarr/ICON2.zarr/SSP3-7.0/3",
    media_type="application/vnd.zarr; version=3",
    roles=["data"],
    title="VSM ICON projection Level 3",
    description="Model: ICON \nLevel: 3 \nExperiment: SSP3-7.0 \n Resolution: high \n Time: 2015-2049",
)
asset_icon_ssp3_3.extra_fields.update({
    "xarray:open_zarr_kwargs": {"zarr_format": 3, "consolidated": True},
})
item_icon.add_asset("ssp3-3", asset_icon_ssp3_3)

# %%
item_nemo = pystac.Item(
    id="IFS-NEMO",
    geometry=geometry,
    bbox=bbox,
    datetime=None,  # because it's a time range
    properties={
        "title": "Volumetric soil moisture IFS-NEMO",
        "description": "IFS-NEMO couples ECMWF's IFS atmosphere model with the NEMO ocean and SI3 sea-ice components. This dataset combines a historical simulation (1990-2014) with its direct continuation under the SSP3-7.0 projection (2015-2049), together spanning 60 years. The atmosphere is resolved at 5 km (TCo2559 grid), while the ocean and sea ice run at 1/12 degree (<9 km, eORCA12 grid).",
        "start_datetime": datetime(1990, 1, 1).isoformat() + "Z",
        "end_datetime": datetime(2049, 12, 31).isoformat() + "Z",
    },
)

# item_nemo.links = [link for link in item_nemo.links if link.href is not None]

# %%
asset_nemo_hist_1 = pystac.Asset(
    href=f"{link}/zarr/IFS-NEMO.zarr/hist/1",
    media_type="application/vnd.zarr; version=3",
    roles=["data"],
    title="VSM IFS-NEMO historical simulation Level 1",
    description="Model: IFS-NEMO \nLevel: 1 \nExperiment: hist \n Resolution: high \n Time: 1990-2014",
)

asset_nemo_hist_1.extra_fields.update({
    "xarray:open_zarr_kwargs": {
        "zarr_format": 3,
        "consolidated": True,
    },
})

item_nemo.add_asset("hist-1", asset_nemo_hist_1)


asset_nemo_hist_2 = pystac.Asset(
    href=f"{link}/zarr/IFS-NEMO.zarr/hist/2",
    media_type="application/vnd.zarr; version=3",
    roles=["data"],
    title="VSM IFS-NEMO historical simulation Level 2",
    description="Model: IFS-NEMO \nLevel: 2 \nExperiment: hist \n Resolution: high \n Time: 1990-2014",
)

asset_nemo_hist_2.extra_fields.update({
    "xarray:open_zarr_kwargs": {
        "zarr_format": 3,
        "consolidated": True,
    },
})

item_nemo.add_asset("hist-2", asset_nemo_hist_2)


asset_nemo_hist_3 = pystac.Asset(
    href=f"{link}/zarr/IFS-NEMO.zarr/hist/3",
    media_type="application/vnd.zarr; version=3",
    roles=["data"],
    title="VSM IFS-NEMO historical simulation Level 3",
    description="Model: IFS-NEMO \nLevel: 3 \nExperiment: hist \n Resolution: high \n Time: 1990-2014",
)

asset_nemo_hist_3.extra_fields.update({
    "xarray:open_zarr_kwargs": {
        "zarr_format": 3,
        "consolidated": True,
    },
})

item_nemo.add_asset("hist-3", asset_nemo_hist_3)

# %%
asset_nemo_ssp3_1 = pystac.Asset(
    href=f"{link}/zarr/IFS-NEMO.zarr/SSP3-7.0/1",
    media_type="application/vnd.zarr; version=3",
    roles=["data"],
    title="VSM IFS-NEMO projection Level 1",
    description="Model: IFS-NEMO \nLevel: 1 \nExperiment: SSP3-7.0 \n Resolution: high \n Time: 2015-2049",
)
asset_nemo_ssp3_1.extra_fields.update({
    "xarray:open_zarr_kwargs": {"zarr_format": 3, "consolidated": True},
})
item_nemo.add_asset("ssp3-1", asset_nemo_ssp3_1)


asset_nemo_ssp3_2 = pystac.Asset(
    href=f"{link}/zarr/IFS-NEMO.zarr/SSP3-7.0/2",
    media_type="application/vnd.zarr; version=3",
    roles=["data"],
    title="VSM IFS-NEMO projection Level 2",
    description="Model: IFS-NEMO \nLevel: 2 \nExperiment: SSP3-7.0 \n Resolution: high \n Time: 2015-2049",
)
asset_nemo_ssp3_2.extra_fields.update({
    "xarray:open_zarr_kwargs": {"zarr_format": 3, "consolidated": True},
})
item_nemo.add_asset("ssp3-2", asset_nemo_ssp3_2)


asset_nemo_ssp3_3 = pystac.Asset(
    href=f"{link}/zarr/IFS-NEMO.zarr/SSP3-7.0/3",
    media_type="application/vnd.zarr; version=3",
    roles=["data"],
    title="VSM IFS-NEMO projection Level 3",
    description="Model: IFS-NEMO \nLevel: 3 \nExperiment: SSP3-7.0 \n Resolution: high \n Time: 2015-2049",
)
asset_nemo_ssp3_3.extra_fields.update({
    "xarray:open_zarr_kwargs": {"zarr_format": 3, "consolidated": True},
})
item_nemo.add_asset("ssp3-3", asset_nemo_ssp3_3)

# %%
item_fesom_sn = pystac.Item(
    id="IFS-FESOM-story-nudging",
    geometry=geometry,
    bbox=bbox,
    datetime=None,  # because it's a time range
    properties={
        "title": "Volumetric soil moisture IFS-FESOM story-nudging",
        "description": "IFS-FESOM storyline simulations nudge the model towards three climate storylines - a control run (cont), a historical run (hist), and a +2K warmer-world scenario (Tplus2.0K) - each run as a 5-member ensemble (realizations 1-5) at high (10 km) resolution to sample internal variability alongside the imposed climate signal. Data covers 2017-2025.",
        "start_datetime": datetime(2017, 1, 1).isoformat() + "Z",
        "end_datetime": datetime(2025, 12, 31).isoformat() + "Z",
    },
)

# item_fesom_sn.links = [link for link in item_fesom_sn.links if link.href is not None]

# %%
asset_fesom_sn_cont_1 = pystac.Asset(
    href=f"{link}/zarr/IFS_FESOM_story_nudging.zarr/cont/1",
    media_type="application/vnd.zarr; version=3",
    roles=["data"],
    title="VSM IFS-FESOM story-nudging cont Level 1",
    description="Model: IFS-FESOM \nActivity: story-nudging \nExperiment: cont \nLevel: 1 \nRealizations: 1-5 \nResolution: high \nTime: 2017-2025",
)
asset_fesom_sn_cont_1.extra_fields.update({
    "xarray:open_zarr_kwargs": {"zarr_format": 3, "consolidated": True},
})
item_fesom_sn.add_asset("cont-1", asset_fesom_sn_cont_1)


asset_fesom_sn_cont_2 = pystac.Asset(
    href=f"{link}/zarr/IFS_FESOM_story_nudging.zarr/cont/2",
    media_type="application/vnd.zarr; version=3",
    roles=["data"],
    title="VSM IFS-FESOM story-nudging cont Level 2",
    description="Model: IFS-FESOM \nActivity: story-nudging \nExperiment: cont \nLevel: 2 \nRealizations: 1-5 \nResolution: high \nTime: 2017-2025",
)
asset_fesom_sn_cont_2.extra_fields.update({
    "xarray:open_zarr_kwargs": {"zarr_format": 3, "consolidated": True},
})
item_fesom_sn.add_asset("cont-2", asset_fesom_sn_cont_2)


asset_fesom_sn_cont_3 = pystac.Asset(
    href=f"{link}/zarr/IFS_FESOM_story_nudging.zarr/cont/3",
    media_type="application/vnd.zarr; version=3",
    roles=["data"],
    title="VSM IFS-FESOM story-nudging cont Level 3",
    description="Model: IFS-FESOM \nActivity: story-nudging \nExperiment: cont \nLevel: 3 \nRealizations: 1-5 \nResolution: high \nTime: 2017-2025",
)
asset_fesom_sn_cont_3.extra_fields.update({
    "xarray:open_zarr_kwargs": {"zarr_format": 3, "consolidated": True},
})
item_fesom_sn.add_asset("cont-3", asset_fesom_sn_cont_3)

# %%
asset_fesom_sn_hist_1 = pystac.Asset(
    href=f"{link}/zarr/IFS_FESOM_story_nudging.zarr/hist/1",
    media_type="application/vnd.zarr; version=3",
    roles=["data"],
    title="VSM IFS-FESOM story-nudging hist Level 1",
    description="Model: IFS-FESOM \nActivity: story-nudging \nExperiment: hist \nLevel: 1 \nRealizations: 1-5 \nResolution: high \nTime: 2017-2025",
)
asset_fesom_sn_hist_1.extra_fields.update({
    "xarray:open_zarr_kwargs": {"zarr_format": 3, "consolidated": True},
})
item_fesom_sn.add_asset("hist-1", asset_fesom_sn_hist_1)


asset_fesom_sn_hist_2 = pystac.Asset(
    href=f"{link}/zarr/IFS_FESOM_story_nudging.zarr/hist/2",
    media_type="application/vnd.zarr; version=3",
    roles=["data"],
    title="VSM IFS-FESOM story-nudging hist Level 2",
    description="Model: IFS-FESOM \nActivity: story-nudging \nExperiment: hist \nLevel: 2 \nRealizations: 1-5 \nResolution: high \nTime: 2017-2025",
)
asset_fesom_sn_hist_2.extra_fields.update({
    "xarray:open_zarr_kwargs": {"zarr_format": 3, "consolidated": True},
})
item_fesom_sn.add_asset("hist-2", asset_fesom_sn_hist_2)


asset_fesom_sn_hist_3 = pystac.Asset(
    href=f"{link}/zarr/IFS_FESOM_story_nudging.zarr/hist/3",
    media_type="application/vnd.zarr; version=3",
    roles=["data"],
    title="VSM IFS-FESOM story-nudging hist Level 3",
    description="Model: IFS-FESOM \nActivity: story-nudging \nExperiment: hist \nLevel: 3 \nRealizations: 1-5 \nResolution: high \nTime: 2017-2025",
)
asset_fesom_sn_hist_3.extra_fields.update({
    "xarray:open_zarr_kwargs": {"zarr_format": 3, "consolidated": True},
})
item_fesom_sn.add_asset("hist-3", asset_fesom_sn_hist_3)

# %%
asset_fesom_sn_Tplus2_1 = pystac.Asset(
    href=f"{link}/zarr/IFS_FESOM_story_nudging.zarr/Tplus2.0K/1",
    media_type="application/vnd.zarr; version=3",
    roles=["data"],
    title="VSM IFS-FESOM story-nudging Tplus2.0K Level 1",
    description="Model: IFS-FESOM \nActivity: story-nudging \nExperiment: Tplus2.0K \nLevel: 1 \nRealizations: 1-5 \nResolution: high \nTime: 2017-2025",
)
asset_fesom_sn_Tplus2_1.extra_fields.update({
    "xarray:open_zarr_kwargs": {"zarr_format": 3, "consolidated": True},
})
item_fesom_sn.add_asset("Tplus2-1", asset_fesom_sn_Tplus2_1)


asset_fesom_sn_Tplus2_2 = pystac.Asset(
    href=f"{link}/zarr/IFS_FESOM_story_nudging.zarr/Tplus2.0K/2",
    media_type="application/vnd.zarr; version=3",
    roles=["data"],
    title="VSM IFS-FESOM story-nudging Tplus2.0K Level 2",
    description="Model: IFS-FESOM \nActivity: story-nudging \nExperiment: Tplus2.0K \nLevel: 2 \nRealizations: 1-5 \nResolution: high \nTime: 2017-2025",
)
asset_fesom_sn_Tplus2_2.extra_fields.update({
    "xarray:open_zarr_kwargs": {"zarr_format": 3, "consolidated": True},
})
item_fesom_sn.add_asset("Tplus2-2", asset_fesom_sn_Tplus2_2)


asset_fesom_sn_Tplus2_3 = pystac.Asset(
    href=f"{link}/zarr/IFS_FESOM_story_nudging.zarr/Tplus2.0K/3",
    media_type="application/vnd.zarr; version=3",
    roles=["data"],
    title="VSM IFS-FESOM story-nudging Tplus2.0K Level 3",
    description="Model: IFS-FESOM \nActivity: story-nudging \nExperiment: Tplus2.0K \nLevel: 3 \nRealizations: 1-5 \nResolution: high \nTime: 2017-2025",
)
asset_fesom_sn_Tplus2_3.extra_fields.update({
    "xarray:open_zarr_kwargs": {"zarr_format": 3, "consolidated": True},
})
item_fesom_sn.add_asset("Tplus2-3", asset_fesom_sn_Tplus2_3)

# %%
collection.add_item(item_fesom)
collection.add_item(item_icon)
collection.add_item(item_nemo)
collection.add_item(item_fesom_sn)


collection.links = [link for link in collection.links if link.get_href() is not None]

# %%
print(collection.to_dict())
# Out:
# {'type': 'Collection', 'id': 'climatedt-vsw', 'stac_version': '1.1.0', 'description': 'The Destination Earth Climate Change Adaptation Digital Twin (Climate DT) is an operational modeling system that delivers globally consistent, high-resolution climate and climate-impact data at spatial resolutions fine enough to capture many climate change effects and extreme weather events. The system supports two main use cases: projecting how the climate system may evolve over multi-decadal periods, and evaluating what-if scenarios, both of which help inform climate adaptation planning throughout Europe. This collection draws on Generation 2 data and covers the volumetric soil moisture (vsw). More information here: https://platform.destine.eu/services/documents-and-api/doc/?service_name=climate-dt-user-guide', 'links': [], 'stac_extensions': ['https://stac-extensions.github.io/zarr/v1.1.0/schema.json'], 'title': 'DestinE Climate Change Adaptation Digital Twin Volumetric Soil moisture', 'extent':
# ...

# %%
import requests

# collection_url = "https://dev.stac.eodc.eu/ingestion/v1/collections"
collection_url = "https://stac.eodc.eu/ingestion/v1/collections"

# %%
# Send a POST request to ingest the STAC Collection
# collection_ingest_response = requests.post(collection_url, json=collection.to_dict(), auth=("", ""))
collection_ingest_response = requests.post(collection_url, json=collection.to_dict(), auth=(user, key))

# Print the response
print("STAC Collection Ingest Response:", collection_ingest_response.text)
# Out:
# STAC Collection Ingest Response: {"id":"climatedt-vsw","description":"The Destination Earth Climate Change Adaptation Digital Twin (Climate DT) is an operational modeling system that delivers globally consistent, high-resolution climate and climate-impact data at spatial resolutions fine enough to capture many climate change effects and extreme weather events. The system supports two main use cases: projecting how the climate system may evolve over multi-decadal periods, and evaluating what-if scenarios, both of which help inform climate adaptation planning throughout Europe. This collection draws on Generation 2 data and covers the volumetric soil moisture (vsw). More information here: https://platform.destine.eu/services/documents-and-api/doc/?service_name=climate-dt-user-guide","stac_version":"1.1.0","links":[{"rel":"items","type":"application/geo+json","href":"https://stac.eodc.eu/ingestion/v1/collections/climatedt-vsw/items"},{"rel":"parent","type":"application/json","href":"htt
# ...

# %%
items_url = f"{collection_url}/climatedt-vsw/items"

# %%
item_fesom.links = [link for link in item_fesom.links if link.get_href() is not None]
response_fesom = requests.post(items_url, json=item_fesom.to_dict(), auth=(user, key))
print("IFS-FESOM:", response_fesom.status_code, response_fesom.text)

item_icon.links = [link for link in item_icon.links if link.get_href() is not None]
response_icon = requests.post(items_url, json=item_icon.to_dict(), auth=(user, key))
print("ICON:", response_icon.status_code, response_icon.text)

item_nemo.links = [link for link in item_nemo.links if link.get_href() is not None]
response_nemo = requests.post(items_url, json=item_nemo.to_dict(), auth=(user, key))
print("IFS-NEMO:", response_nemo.status_code, response_nemo.text)


item_fesom_sn.links = [link for link in item_fesom_sn.links if link.get_href() is not None]
response_fesom_sn = requests.post(items_url, json=item_fesom_sn.to_dict(), auth=(user, key))
print("IFS-FESOM-story-nudging:", response_fesom_sn.status_code, response_fesom_sn.text)
# Out:
# IFS-FESOM: 201 {"bbox":[9.47,46.34,17.22,49.04],"type":"Feature","geometry":{"type":"Polygon","coordinates":[[[9.47,46.34],[17.22,46.34],[17.22,49.04],[9.47,49.04],[9.47,46.34]]]},"properties":{"title":"Volumetric soil moisture IFS-FESOM","description":"IFS-FESOM couples ECMWF's IFS atmosphere model with AWI's FESOM2 ocean and sea-ice model in a sequential, single-executable framework, exchanging fluxes and surface fields hourly via Gaussian distance-weighted remapping. It also includes indirect wave coupling through ecWAM and direct runoff coupling from IFS to FESOM, and has been used both for the core Climate DT simulations and for high-resolution (10km) storyline experiments.","datetime":null,"start_datetime":"1990-01-01T00:00:00Z","end_datetime":"2049-12-31T00:00:00Z"},"id":"IFS-FESOM","stac_version":"1.1.0","assets":{"hist-1":{"href":"https://objects.eodc.eu/68e13833a1624f43ba2cac01376a18af:destine-climate-dt/vsw/zarr/IFS-FESOM.zarr/hist/1","type":"application/vnd.zarr; version=
# ...

# %%
# import requests
# # vpp_collection_url = "https://dev.stac.eodc.eu/ingestion/v1/collections/climatedt-vsw"
# vpp_collection_url = "https://stac.eodc.eu/ingestion/v1/collections/climatedt-vsw"
# collection_delete_response = requests.delete(vpp_collection_url, auth=(user, key))
# if collection_delete_response.status_code in (200, 204):
#     print("STAC Collection deleted successfully.")
# else:
#     print("Failed to delete STAC Collection:", collection_delete_response.text)
# Out:
# STAC Collection deleted successfully.
